# %%
from Bio import Phylo
import pandas as pd

# %%
# 系統樹読み込み
tree = Phylo.read("/Users/hrkito0902/iwsk_lab/data/raw/ar122_r202.selected.internal_renamed.tree", "newick")

# %%
# tree オブジェクトの中身を確認
tree.clade.clades
# Out:
# [Clade(branch_length=0.07178, name='node2_'),
#  Clade(branch_length=1.46491, name='GB_GCA_001873845.1')]

# %%
# tree の末端の葉
# tree.get_terminals()

# %%
# 祖先状態推定データの読み込み
# Possesion=0の行は削除済み
# Possesion=0.5も除く
df = pd.read_table("/Users/hrkito0902/iwsk_lab/data/raw/ko_gn_possession.archaea.txt", names=["OG", "Node", "Possesion"])
print(df.shape)
print(df)
# Out:
# (1690463, 3)
#              OG                Node  Possesion
# 0        K00003              node0_        1.0
# 1        K00003              node1_        1.0
# 2        K00003              node2_        1.0
# 3        K00003  GB_GCA_001873845.1        1.0
# 4        K00003              node3_        1.0
# ...         ...                 ...        ...
# 1690458  K24410            node550_        1.0
# 1690459  K24410  RS_GCF_003111625.1        1.0
# 1690460  K24410  GB_GCA_902774605.1        1.0
# 1690461  K24410  RS_GCF_003814835.1        1.0
# 1690462  K24410  RS_GCF_900769095.1        1.0
#
# [1690463 rows x 3 columns]
